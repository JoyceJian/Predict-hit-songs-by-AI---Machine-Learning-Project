# %%
# libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load in hit song files
d1990 = pd.read_csv('1990data_final.csv')
d2000 = pd.read_csv('2000data_final.csv')
d2010 = pd.read_csv('2010data_final.csv')
d2019 = pd.read_csv('2019data_final.csv')
df = pd.read_csv('2019data_final.csv')

# %%
d2019.describe()
# Out:
#         Unnamed: 0  acousticness  danceability    duration_ms       energy  \
# count  1099.000000   1099.000000   1099.000000    1099.000000  1099.000000
# mean    549.000000      0.228202      0.689651  196798.374886     0.618207
# std     317.398278      0.227280      0.142515   35009.261746     0.159219
# min       0.000000      0.000022      0.179000   96333.000000     0.111000
# 25%     274.500000      0.051000      0.591000  177614.000000     0.512000
# 50%     549.000000      0.145000      0.698000  194088.000000     0.624000
# 75%     823.500000      0.354000      0.795000  214035.000000     0.734000
# max    1098.000000      0.978000      0.970000  312820.000000     0.984000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       1099.000000  1099.000000  1099.000000  1099.000000  1099.000000
# mean           0.003006     5.182894     0.173276    -6.175301     0.653321
# ...

# %%
from math import pi

# %%
df1 = pd.read_csv('2019data_final.csv')
df1 = df1[['acousticness',
 'danceability',
 #'duration_ms',
 'energy',
 'instrumentalness',
 'liveness',
  'mode',
 'speechiness',
 #'tempo',
 'valence']]
list(df)
# Out:
# ['acousticness',
#  'danceability',
#  'energy',
#  'instrumentalness',
#  'liveness',
#  'mode',
#  'speechiness',
#  'valence']

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'acousticness',
#  'analysis_url',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'id',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'track_href',
#  'type',
#  'uri',
#  'valence']

# %%
df.loc['mean'] = df.mean().copy()
# Out:
# C:\Users\yidan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df[-1:]
# Out:
#       acousticness  danceability    energy  instrumentalness  liveness  \
# mean      0.228202      0.689651  0.618207          0.003006  0.173276
#
#           mode  speechiness   valence
# mean  0.653321     0.130081  0.493921

# %%
df[:1]
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  mode  \
# 0         0.229         0.717   0.653               0.0     0.101   1.0
#
#    speechiness  valence
# 0       0.0658    0.412

# %%
df.index = df.index.set_names(['index'])
df
# Out:
#        acousticness  danceability    energy  instrumentalness  liveness  \
# index
# 0          0.229000      0.717000  0.653000          0.000000  0.101000
# 1          0.297000      0.752000  0.488000          0.000009  0.093600
# 2          0.164000      0.335000  0.625000          0.000000  0.070800
# 3          0.005130      0.834000  0.730000          0.000000  0.124000
# 4          0.556000      0.760000  0.479000          0.000000  0.070300
# 5          0.193000      0.579000  0.904000          0.000000  0.064000
# 6          0.191000      0.687000  0.792000          0.000000  0.167000
# 7          0.643000      0.754000  0.424000          0.000000  0.065200
# 8          0.614000      0.589000  0.472000          0.000000  0.505000
# 9          0.591000      0.675000  0.369000          0.000000  0.097100
# 10         0.920000      0.319000  0.210000          0.000081  0.138000
# 11         0.085200      0.897000  0.662000          0.000000  0.534000
# ...

# %%
df.columns
# Out:
# Index(['acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'mode', 'speechiness', 'valence'],
#       dtype='object')

# %%
# ------- PART 1: Create background
 
# number of variable
categories=list(df)[0:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([0,0.5,1], ["0","0.5","1"], color="grey", size=7)
plt.ylim(0,1)

  
# ---------- Part 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=df.loc['mean'].values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Mean")
ax.fill(angles, values, 'b', alpha=0.1)
 
# # Ind2
# values=df.loc[1].drop('group').values.flatten().tolist()
# values += values[:1]
# ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
# ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.savefig('radar2019.png')

# %%
values
# Out:
# [0.2282015746132846,
#  0.6896505914467698,
#  0.6182065514103721,
#  0.0030062898544131046,
#  0.17327616014558703,
#  0.6533212010919017,
#  0.13008125568698825,
#  0.49392138307552363,
#  0.2282015746132846]
