# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
data1990 = pd.read_csv("https://hyd123.s3.us-east-2.amazonaws.com/updated_data/1990data_final.csv")
data2000 = pd.read_csv("https://hyd123.s3.us-east-2.amazonaws.com/updated_data/2000data_final.csv")
data2010 = pd.read_csv("https://hyd123.s3.us-east-2.amazonaws.com/updated_data/2010data_final.csv")
data2019 = pd.read_csv("https://hyd123.s3.us-east-2.amazonaws.com/updated_data/2019data_final.csv")#("https://hyd123.s3.us-east-2.amazonaws.com/2019data_redo.csv")

# %%
data1990 = pd.read_csv("https://hyd123.s3.us-east-2.amazonaws.com/updated_data/1990data_cleaned.csv")
data2000 = pd.read_csv("https://hyd123.s3.us-east-2.amazonaws.com/updated_data/2000data_cleaned.csv")
data2010 = pd.read_csv("https://hyd123.s3.us-east-2.amazonaws.com/updated_data/2010data_cleaned.csv")
data2019 = pd.read_csv("https://hyd123.s3.us-east-2.amazonaws.com/updated_data/2019data_cleaned.csv")

# %%
data1990.columns

# %%
# label all dfs by publish year
data1990['year'] = 0
data2000['year'] = 1
data2010['year'] = 2
data2019['year'] = 3
data1990.head()
# Out:
#    Unnamed: 0  acousticness  \
# 0           0        0.7360
# 1           1        0.0561
# 2           2        0.6570
# 3           3        0.0287
# 4           4        0.3340
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/1NCu...         0.780
# 1  https://api.spotify.com/v1/audio-analysis/51q3...         0.631
# 2  https://api.spotify.com/v1/audio-analysis/5z3Z...         0.401
# 3  https://api.spotify.com/v1/audio-analysis/0UAE...         0.862
# 4  https://api.spotify.com/v1/audio-analysis/1s12...         0.713
#
#    duration_ms  energy                      id  instrumentalness  key  \
# 0       322133   0.565  1NCuYqMc8hKMb4cpNTcJbD          0.002690    3
# 1       330933   0.935  51q3nDYWAqPY4hlgKEbP6j          0.152000    1
# 2       211973   0.285  5z3ZDMP02xF33yCvPFnct3          0.000011   11
# 3       215040   0.918  0UAEHlFR79k9CJvknSGUNf          0.000001   10
# 4       274093   0.432  1s12gYsPeTNQ6znow46nmp          0.000299   11
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0    0.0630    -7.320     0       0.0306  101.967               4
# 1    0.6340    -8.340     0       0.0587  109.122               4
# 2    0.1580   -11.005     1       0.0327  130.465               4
# 3    0.0492    -7.325     0       0.1080  124.811               4
# 4    0.0674   -12.639     0       0.0300  118.955               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/1NCuYqMc8hKM...  audio_features
# 1  https://api.spotify.com/v1/tracks/51q3nDYWAqPY...  audio_features
# 2  https://api.spotify.com/v1/tracks/5z3ZDMP02xF3...  audio_features
# 3  https://api.spotify.com/v1/tracks/0UAEHlFR79k9...  audio_features
# 4  https://api.spotify.com/v1/tracks/1s12gYsPeTNQ...  audio_features
#
#                                     uri  valence  year
# 0  spotify:track:1NCuYqMc8hKMb4cpNTcJbD    0.365     0
# 1  spotify:track:51q3nDYWAqPY4hlgKEbP6j    0.678     0
# 2  spotify:track:5z3ZDMP02xF33yCvPFnct3    0.267     0
# 3  spotify:track:0UAEHlFR79k9CJvknSGUNf    0.651     0
# 4  spotify:track:1s12gYsPeTNQ6znow46nmp    0.445     0

# %%
data1990['loudness'] = data1990['loudness'] + 100
data2000['loudness'] = data2000['loudness'] + 100
data2010['loudness'] = data2010['loudness'] + 100
data2019['loudness'] = data2019['loudness'] + 100
data1990
# Out:
#      Unnamed: 0  acousticness  \
# 0             0      0.736000
# 1             1      0.056100
# 2             2      0.657000
# 3             3      0.028700
# 4             4      0.334000
# 5             5      0.191000
# 6             6      0.198000
# 7             7      0.077100
# 8             8      0.902000
# 9             9      0.191000
# 10           10      0.098500
# 11           11      0.408000
# 12           12      0.219000
# 13           13      0.020800
# 14           14      0.453000
# 15           15      0.012900
# 16           16      0.199000
# 17           17      0.024700
# 18           18      0.614000
# 19           19      0.003280
# 20           20      0.006420
# 21           21      0.109000
# 22           22      0.008970
# 23           23      0.451000
# 24           24      0.309000
# 25           25      0.000008
# 26           26      0.032500
# 27           27      0.157000
# 28           28      0.723000
# 29           29      0.800000
# ..          ...           ...
# 403        1106      0.002440
# 404        1114      0.144000
# 405        1127      0.321000
# 406        1129      0.748000
# 407        1132      0.004780
# 408        1134      0.000048
# 409        1135      0.800000
# 410        1137      0.431000
# 411        1140      0.189000
# 412        1141      0.339000
# 413        1142      0.065600
# 414        1145      0.531000
# 415        1146      0.565000
# 416        1147      0.467000
# 417        1148      0.007310
# 418        1149      0.394000
# 419        1150      0.004400
# 420        1154      0.000351
# 421        1155      0.513000
# 422        1165      0.102000
# 423        1166      0.004350
# 424        1168      0.242000
# 425        1169      0.901000
# 426        1171      0.087600
# 427        1174      0.224000
# 428        1175      0.022100
# 429        1177      0.744000
# 430        1178      0.000042
# 431        1182      0.067700
# 432        1183      0.012200
#
#                                           analysis_url  danceability  \
# 0    https://api.spotify.com/v1/audio-analysis/1NCu...        0.7800
# 1    https://api.spotify.com/v1/audio-analysis/51q3...        0.6310
# 2    https://api.spotify.com/v1/audio-analysis/5z3Z...        0.4010
# 3    https://api.spotify.com/v1/audio-analysis/0UAE...        0.8620
# 4    https://api.spotify.com/v1/audio-analysis/1s12...        0.7130
# 5    https://api.spotify.com/v1/audio-analysis/3RMe...        0.5410
# 6    https://api.spotify.com/v1/audio-analysis/5JGd...        0.4050
# 7    https://api.spotify.com/v1/audio-analysis/3Cx4...        0.7120
# 8    https://api.spotify.com/v1/audio-analysis/3ZCT...        0.7040
# 9    https://api.spotify.com/v1/audio-analysis/7Lr4...        0.4670
# 10   https://api.spotify.com/v1/audio-analysis/5OoH...        0.6880
# 11   https://api.spotify.com/v1/audio-analysis/5fsU...        0.5110
# 12   https://api.spotify.com/v1/audio-analysis/5tVA...        0.6300
# 13   https://api.spotify.com/v1/audio-analysis/4E6c...        0.5830
# 14   https://api.spotify.com/v1/audio-analysis/3fPq...        0.6690
# 15   https://api.spotify.com/v1/audio-analysis/58nU...        0.6880
# 16   https://api.spotify.com/v1/audio-analysis/6h3f...        0.7760
# 17   https://api.spotify.com/v1/audio-analysis/4urd...        0.2670
# 18   https://api.spotify.com/v1/audio-analysis/599w...        0.1810
# 19   https://api.spotify.com/v1/audio-analysis/0UUp...        0.7580
# 20   https://api.spotify.com/v1/audio-analysis/4ZpX...        0.3450
# 21   https://api.spotify.com/v1/audio-analysis/3Mnw...        0.6510
# 22   https://api.spotify.com/v1/audio-analysis/23zz...        0.6290
# 23   https://api.spotify.com/v1/audio-analysis/1mo1...        0.7690
# 24   https://api.spotify.com/v1/audio-analysis/4D13...        0.4540
# 25   https://api.spotify.com/v1/audio-analysis/44uE...        0.2980
# 26   https://api.spotify.com/v1/audio-analysis/4W4w...        0.7150
# 27   https://api.spotify.com/v1/audio-analysis/3oCU...        0.3580
# 28   https://api.spotify.com/v1/audio-analysis/3eIc...        0.6180
# 29   https://api.spotify.com/v1/audio-analysis/1FBu...        0.6710
# ..                                                 ...           ...
# 403  https://api.spotify.com/v1/audio-analysis/6BWR...        0.7050
# 404  https://api.spotify.com/v1/audio-analysis/30tk...        0.7530
# 405  https://api.spotify.com/v1/audio-analysis/4y42...        0.7640
# 406  https://api.spotify.com/v1/audio-analysis/5HQE...        0.4010
# 407  https://api.spotify.com/v1/audio-analysis/0TQB...        0.5240
# 408  https://api.spotify.com/v1/audio-analysis/14NE...        0.0822
# 409  https://api.spotify.com/v1/audio-analysis/3sw3...        0.2280
# 410  https://api.spotify.com/v1/audio-analysis/4L9V...        0.6200
# 411  https://api.spotify.com/v1/audio-analysis/7lVT...        0.6700
# 412  https://api.spotify.com/v1/audio-analysis/6jkq...        0.5490
# 413  https://api.spotify.com/v1/audio-analysis/0wMs...        0.7390
# 414  https://api.spotify.com/v1/audio-analysis/7Cbz...        0.5500
# 415  https://api.spotify.com/v1/audio-analysis/4qUt...        0.3260
# 416  https://api.spotify.com/v1/audio-analysis/5oV1...        0.6780
# 417  https://api.spotify.com/v1/audio-analysis/0TBn...        0.6600
# 418  https://api.spotify.com/v1/audio-analysis/0EpR...        0.4630
# 419  https://api.spotify.com/v1/audio-analysis/6GaF...        0.4960
# 420  https://api.spotify.com/v1/audio-analysis/709N...        0.4420
# 421  https://api.spotify.com/v1/audio-analysis/1VJw...        0.6890
# 422  https://api.spotify.com/v1/audio-analysis/5eNf...        0.6130
# 423  https://api.spotify.com/v1/audio-analysis/4Qxv...        0.6080
# 424  https://api.spotify.com/v1/audio-analysis/0bhG...        0.5200
# 425  https://api.spotify.com/v1/audio-analysis/5Tb6...        0.5000
# 426  https://api.spotify.com/v1/audio-analysis/1K97...        0.6470
# 427  https://api.spotify.com/v1/audio-analysis/3hyj...        0.6540
# 428  https://api.spotify.com/v1/audio-analysis/5C14...        0.7520
# 429  https://api.spotify.com/v1/audio-analysis/390A...        0.6670
# 430  https://api.spotify.com/v1/audio-analysis/65kt...        0.5750
# 431  https://api.spotify.com/v1/audio-analysis/1ygY...        0.7500
# 432  https://api.spotify.com/v1/audio-analysis/6cvM...        0.6290
#
# 10   https://api.spotify.com/v1/tracks/5OoH6HSheF3L...  audio_features
# 11   https://api.spotify.com/v1/tracks/5fsU7AtSTp0z...  audio_features
# 12   https://api.spotify.com/v1/tracks/5tVA6TkbaAH9...  audio_features
# 13   https://api.spotify.com/v1/tracks/4E6cwWJWZw2z...  audio_features
# 14   https://api.spotify.com/v1/tracks/3fPqUl4lPDUQ...  audio_features
# 15   https://api.spotify.com/v1/tracks/58nUOJJpnhO4...  audio_features
# 16   https://api.spotify.com/v1/tracks/6h3fhSQLjcGg...  audio_features
# 17   https://api.spotify.com/v1/tracks/4urd42euwvih...  audio_features
# 18   https://api.spotify.com/v1/tracks/599w7fRMgsd0...  audio_features
# 19   https://api.spotify.com/v1/tracks/0UUpyDCYzkzi...  audio_features
# 20   https://api.spotify.com/v1/tracks/4ZpXHlV2vQVf...  audio_features
# 21   https://api.spotify.com/v1/tracks/3MnwLa9KRUiv...  audio_features
# 22   https://api.spotify.com/v1/tracks/23zzKOubAzAu...  audio_features
# 23   https://api.spotify.com/v1/tracks/1mo1tQypPi59...  audio_features
# 24   https://api.spotify.com/v1/tracks/4D13ulAZI1V7...  audio_features
# 25   https://api.spotify.com/v1/tracks/44uEz0HaEadU...  audio_features
# 26   https://api.spotify.com/v1/tracks/4W4wYHtsrgDi...  audio_features
# 27   https://api.spotify.com/v1/tracks/3oCUfoqrkQia...  audio_features
# 28   https://api.spotify.com/v1/tracks/3eIc0XWlqNkT...  audio_features
# 29   https://api.spotify.com/v1/tracks/1FBuBhNZ8dmj...  audio_features
# ..                                                 ...             ...
# 403  https://api.spotify.com/v1/tracks/6BWRvw630R8z...  audio_features
# 404  https://api.spotify.com/v1/tracks/30tkVyBPF2ZG...  audio_features
# 405  https://api.spotify.com/v1/tracks/4y42JYIIfYXr...  audio_features
# 406  https://api.spotify.com/v1/tracks/5HQEmiV2lKnS...  audio_features
# 407  https://api.spotify.com/v1/tracks/0TQBDoIb0LZP...  audio_features
# 408  https://api.spotify.com/v1/tracks/14NEgZFbFI38...  audio_features
# 409  https://api.spotify.com/v1/tracks/3sw35CloiatY...  audio_features
# 410  https://api.spotify.com/v1/tracks/4L9VA69sfZKK...  audio_features
# 411  https://api.spotify.com/v1/tracks/7lVTsC4S4lhu...  audio_features
# 412  https://api.spotify.com/v1/tracks/6jkqaUJm7Tv0...  audio_features
# 413  https://api.spotify.com/v1/tracks/0wMs7DPFOnTo...  audio_features
# 414  https://api.spotify.com/v1/tracks/7Cbz21BW7tzf...  audio_features
# 415  https://api.spotify.com/v1/tracks/4qUtC2BwFC15...  audio_features
# 416  https://api.spotify.com/v1/tracks/5oV1YjM2rtyZ...  audio_features
# 417  https://api.spotify.com/v1/tracks/0TBn49AjkNuf...  audio_features
# 418  https://api.spotify.com/v1/tracks/0EpRxgIqC79g...  audio_features
# 419  https://api.spotify.com/v1/tracks/6GaFUMG9opnM...  audio_features
# 420  https://api.spotify.com/v1/tracks/709Na7IJRJTn...  audio_features
# 421  https://api.spotify.com/v1/tracks/1VJwtWR6z7Sp...  audio_features
# 422  https://api.spotify.com/v1/tracks/5eNfNxIPecUu...  audio_features
# 423  https://api.spotify.com/v1/tracks/4Qxv2L4JICAW...  audio_features
# 424  https://api.spotify.com/v1/tracks/0bhGTfpajLMj...  audio_features
# 425  https://api.spotify.com/v1/tracks/5Tb6K5YFvUNX...  audio_features
# 426  https://api.spotify.com/v1/tracks/1K97Cp6YcpSR...  audio_features
# 427  https://api.spotify.com/v1/tracks/3hyjOsn9ZPoQ...  audio_features
# 428  https://api.spotify.com/v1/tracks/5C14MgFV6V0l...  audio_features
# 429  https://api.spotify.com/v1/tracks/390AWnOn2rfe...  audio_features
# 430  https://api.spotify.com/v1/tracks/65ktZKQaFa8r...  audio_features
# 431  https://api.spotify.com/v1/tracks/1ygYmvcPeON1...  audio_features
# 432  https://api.spotify.com/v1/tracks/6cvMXP6o9zzi...  audio_features
#
#                                       uri  valence  year
# 0    spotify:track:1NCuYqMc8hKMb4cpNTcJbD   0.3650     0
# 1    spotify:track:51q3nDYWAqPY4hlgKEbP6j   0.6780     0
# 2    spotify:track:5z3ZDMP02xF33yCvPFnct3   0.2670     0
# 3    spotify:track:0UAEHlFR79k9CJvknSGUNf   0.6510     0
# 4    spotify:track:1s12gYsPeTNQ6znow46nmp   0.4450     0
# 5    spotify:track:3RMeOetCdXttthQK0clPuz   0.2320     0
# 6    spotify:track:5JGdpqo9wrRtOZtui5GShI   0.4780     0
# 7    spotify:track:3Cx4yrFaX8CeHwBMReOWXI   0.8950     0
# 8    spotify:track:3ZCTVFBt2Brf31RLEnCkWJ   0.2430     0
# 9    spotify:track:7Lr4XaxGpkAwa37IVgg22k   0.2800     0
# 10   spotify:track:5OoH6HSheF3LbwnGbpKSFa   0.3660     0
# 11   spotify:track:5fsU7AtSTp0zySUf46hwbt   0.3770     0
# 12   spotify:track:5tVA6TkbaAH9QMITTQRrNv   0.6230     0
# 13   spotify:track:4E6cwWJWZw2zWf7VFbH7wf   0.5730     0
# 14   spotify:track:3fPqUl4lPDUQmY0T7dKUv2   0.7230     0
# 15   spotify:track:58nUOJJpnhO4xXVaFN1eao   0.4200     0
# 16   spotify:track:6h3fhSQLjcGgd4cwW009N0   0.7010     0
# 17   spotify:track:4urd42euwvihhC3j1G8Jt2   0.5260     0
# 18   spotify:track:599w7fRMgsd0TBKfKsej0D   0.0861     0
# 19   spotify:track:0UUpyDCYzkziXJ1TM4awHM   0.5060     0
# 20   spotify:track:4ZpXHlV2vQVfPXUvbDSZ92   0.4900     0
# 21   spotify:track:3MnwLa9KRUiv2gNFtWPvib   0.7410     0
# 22   spotify:track:23zzKOubAzAu8xlQdkVvZ2   0.3720     0
# 23   spotify:track:1mo1tQypPi59Unv8vWuNbL   0.9320     0
# 24   spotify:track:4D13ulAZI1V7PG7Zg1Ar7r   0.5980     0
# 25   spotify:track:44uEz0HaEadUrgZefxyKl5   0.5690     0
# 26   spotify:track:4W4wYHtsrgDiivRASVOINL   0.8710     0
# 27   spotify:track:3oCUfoqrkQiapnJk7UL8IE   0.3010     0
# 28   spotify:track:3eIc0XWlqNkT290DfwNyBJ   0.2640     0
# 29   spotify:track:1FBuBhNZ8dmjUBWR58UOQv   0.1730     0
# ..                                    ...      ...   ...
# 403  spotify:track:6BWRvw630R8z2vNMok6quI   0.4560     0
# 404  spotify:track:30tkVyBPF2ZGF2oBnaE6cE   0.4880     0
# 405  spotify:track:4y42JYIIfYXrJ63s5hQQWS   0.5600     0
# 406  spotify:track:5HQEmiV2lKnSO6qa2fsR7x   0.2080     0
# 407  spotify:track:0TQBDoIb0LZPQBKsjirT93   0.1090     0
# 408  spotify:track:14NEgZFbFI38a0TsxaKNoV   0.0298     0
# 409  spotify:track:3sw35CloiatYlfUv8V5oNb   0.0489     0
# 410  spotify:track:4L9VA69sfZKK5HAs5zP22I   0.4530     0
# 411  spotify:track:7lVTsC4S4lhuXNkQ3SYlCS   0.6450     0
# 412  spotify:track:6jkqaUJm7Tv0EWpY28iQq2   0.1050     0
# 413  spotify:track:0wMs7DPFOnToNAoecvAFQc   0.7730     0
# 414  spotify:track:7Cbz21BW7tzfNtUmaUnEfj   0.3010     0
# 415  spotify:track:4qUtC2BwFC154Ha8YQRrkk   0.0677     0
# 416  spotify:track:5oV1YjM2rtyZ55txHHsFUu   0.9190     0
# 417  spotify:track:0TBn49AjkNufCRJ2O5VJ6s   0.9590     0
# 418  spotify:track:0EpRxgIqC79gXUMI8jPMVc   0.5680     0
# 419  spotify:track:6GaFUMG9opnMytdc0lwnQw   0.3880     0
# 420  spotify:track:709Na7IJRJTnmk0M3rBIQg   0.3680     0
# 421  spotify:track:1VJwtWR6z7SpZRwipI12be   0.2090     0
# 422  spotify:track:5eNfNxIPecUutWixq67H5X   0.5080     0
# 423  spotify:track:4Qxv2L4JICAWLFrBV6QeH8   0.6790     0
# 424  spotify:track:0bhGTfpajLMjcYGMwWHy9p   0.4320     0
# 425  spotify:track:5Tb6K5YFvUNXREaGbDLn1m   0.2730     0
# 426  spotify:track:1K97Cp6YcpSRz1VxR1JKVC   0.8820     0
# 427  spotify:track:3hyjOsn9ZPoQEahaDMirx9   0.6110     0
# 428  spotify:track:5C14MgFV6V0lvw6bChmMkz   0.5960     0
# 429  spotify:track:390AWnOn2rfe9FzQjYmxIH   0.2900     0
# 430  spotify:track:65ktZKQaFa8rPsFSy78nJ0   0.5380     0
# 431  spotify:track:1ygYmvcPeON172daCgtPDH   0.9640     0
# 432  spotify:track:6cvMXP6o9zzi2eXj5GrW3X   0.3970     0
#
# [433 rows x 20 columns]

# %%
# combine dfs into one
df = pd.concat([data1990, data2000,data2010,data2019], ignore_index=True,sort=False)

# %%
# only use the feature columns
df = df[['year','acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']]
df = df.dropna(how = 'any')
df.tail()
# Out:
#       year  acousticness  danceability  duration_ms  energy  instrumentalness  \
# 1564     3        0.1520         0.754       242573   0.646          0.000018
# 1565     3        0.4270         0.679       179973   0.443          0.000000
# 1566     3        0.0794         0.816       136366   0.582          0.000006
# 1567     3        0.3630         0.630       174333   0.671          0.000000
# 1568     3        0.5820         0.819       268893   0.458          0.173000
#
#       key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 1564    7    0.1080    94.205     1        0.317  176.089               4
# 1565   10    0.1060    91.472     0        0.153  104.049               4
# 1566    8    0.0916    95.859     1        0.341  160.004               4
# 1567    6    0.1130    93.341     0        0.256   89.921               4
# 1568    4    0.1280    89.777     0        0.167  122.981               4
#
#       valence
# 1564    0.429
# 1565    0.363
# 1566    0.542
# 1567    0.333
# 1568    0.232

# %%
X = df[['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']]
y = df["year"].values#.reshape(-1, 1)
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (1569, 13) (1569,)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler 
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train) 
X_test_scaled = X_scaler.transform(X_test)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn import tree 
clf = tree.DecisionTreeClassifier()

# %%
clf = clf.fit(X_train_scaled, y_train)
clf.score(X_test_scaled, y_test)
# Out:
# 0.30279898218829515

# %%
predictions = clf.predict(X_test_scaled)

# %%
test_result_df = pd.DataFrame({"Predicted": y_test, "Actual": predictions})[["Predicted", "Actual"]]
test_result_df.head()

# %%
feature_names = X.columns
sorted(zip(clf.feature_importances_, feature_names), reverse=True)

# %%
import graphviz
dot_data = tree.export_graphviz( clf, out_file=None, feature_names=feature_names, class_names=["1990","2000","2010","2019"], filled=True, rounded=True, special_characters=True)

import pydotplus
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_png('music.png')
graph = graphviz.Source(dot_data) 
graph

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier 
rf = RandomForestClassifier(n_estimators=200) 
rf = rf.fit(X_train_scaled, y_train) 
rf.score(X_test_scaled, y_test)
feature_names = X.columns
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.12328684636065593, 'loudness'),
#  (0.11993429707024811, 'duration_ms'),
#  (0.09826628820103413, 'speechiness'),
#  (0.09519187787408458, 'energy'),
#  (0.08902500821340813, 'valence'),
#  (0.08682015940861504, 'tempo'),
#  (0.08614483379962617, 'acousticness'),
#  (0.08496357019022112, 'danceability'),
#  (0.0826466682496568, 'liveness'),
#  (0.06372236721156348, 'instrumentalness'),
#  (0.05155781512019862, 'key'),
#  (0.013468917343914366, 'mode'),
#  (0.004971350956773764, 'time_signature')]

# %%
rf.score(X_test_scaled, y_test)
# Out:
# 0.44529262086513993

# %% [markdown]
# ### Neural Network

# %%
from numpy.random import seed 
seed(42)

# %%
from keras.utils import to_categorical
y_train_cate = to_categorical(y_train)
y_test_cate = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential 
model_neural = Sequential()

# %%
from tensorflow.keras.layers import Dense 
number_inputs = 13 
number_hidden_nodes = 100 
model_neural.add(Dense(units=number_hidden_nodes, activation='relu', input_dim=number_inputs))

for i in range(11):
    model_neural.add(Dense(units=number_hidden_nodes, activation='relu')) 

number_classes = 4 
model_neural.add(Dense(units=number_classes, activation='softmax'))
model_neural.summary()

# %%
model_neural.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model_neural.fit( X_train_scaled, y_train_cate, epochs=20, shuffle=True, verbose=2 )
model_loss, model_accuracy = model_neural.evaluate( X_test_scaled, y_test_cate, verbose=2) 
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %% [markdown]
# ### K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
train_scores = [] 
test_scores = []
for k in range(1, 20, 2):
      knn = KNeighborsClassifier(n_neighbors=k)
      knn.fit(X_train_scaled, y_train)  
      train_score = knn.score(X_train_scaled, y_train)
      test_score = knn.score(X_test_scaled, y_test) 
      train_scores.append(train_score) 
      test_scores.append(test_score)
      print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")

# %%
plt.plot(range(1, 20, 2), train_scores, marker='o') 
plt.plot(range(1, 20, 2), test_scores, marker="x") 
plt.xlabel("k neighbors") 
plt.ylabel("Testing accuracy Score")
plt.show()
plt.savefig("K_Neighbors.png")

# %%
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train_scaled, y_train) 
print('k=11 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train_scaled, y_train)
gnb.score(X_test_scaled, y_test)
# Out:
# 0.37404580152671757

# %%
from sklearn.naive_bayes import MultinomialNB
Mnb = MultinomialNB()
Mnb.fit(X_train_scaled, y_train)
Mnb.score(X_test_scaled, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a959bd22cb73> in <module>
#       1 from sklearn.naive_bayes import MultinomialNB
#       2 Mnb = MultinomialNB()
# ----> 3 Mnb.fit(X_train_scaled, y_train)
#       4 Mnb.score(X_test_scaled, y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     608         self.feature_count_ = np.zeros((n_effective_classes, n_features),
#     609                                        dtype=np.float64)
# --> 610         self._count(X, Y)
#     611         alpha = self._check_alpha()
#     612         self._update_feature_log_prob(alpha)
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in _count(self, X, Y)
#     712         """Count and smooth feature occurrences."""
#     713         if np.any((X.data if issparse(X) else X) < 0):
# --> 714             raise ValueError("Input X must be non-negative")
#     715         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     716         self.class_count_ += Y.sum(axis=0)
#
# ValueError: Input X must be non-negative

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC
model_svc = SVC(kernel='linear') 
model_svc.fit(X_train_scaled, y_train)

from sklearn.metrics import classification_report
predictions = model_svc.predict(X_test_scaled)

print(classification_report(y_test, predictions, target_names=["1990", "2000","2010","2019"]))

# %%
svm_predictions = model_svc.predict(X_test_scaled) 
from sklearn.metrics import confusion_matrix 
cm = confusion_matrix(y_test, svm_predictions) 
cm

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression 
classifier = LogisticRegression()
classifier.fit(X_train_scaled, y_train)

print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")

# %%
from sklearn.linear_model import LogisticRegressionCV 
classifier = LogisticRegressionCV(multi_class="multinomial")
classifier.fit(X_train_scaled, y_train)

print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")

# %%
from sklearn.linear_model import RidgeClassifierCV
classifier = RidgeClassifierCV()
classifier.fit(X_train_scaled, y_train)

print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
