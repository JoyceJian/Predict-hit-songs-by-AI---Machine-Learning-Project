# %%
import pandas as pd

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2

# %%
market = [ "AD", "AR", "AT", "AU", "BE", "BG", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", 
      "CZ", "DE", "DK", "DO", "EC", "EE", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", 
      "ID", "IE", "IS", "IT", "JP", "LI", "LT", "LU", "LV", "MC", "MT", "MX", "MY", "NI", "NL", 
      "NO", "NZ", "PA", "PE", "PH", "PL", "PT", "PY", "SE", "SG", "SK", "SV", "TH", "TR", "TW", 
      "US", "UY", "VN" ]

# %%
import billboard
from time import sleep

# %%
i = 1
charts2019 = []
while i <= 12:

  if i < 10:
    date2019 = "2019-0" + str(i) +"-01"
  else:
    date2019 = "2019-" + str(i) +"-01"

  charts = billboard.ChartData('hot-100', date=date2019, fetch=True, timeout=25)
  # print(charts)
  charts2019.append(charts)
  print(f"{date2019} chart appended.")

  i += 1
  sleep(180)

# %%
charts2019

# %%
song_titles_2019 = []

for chart in charts2019:
    count = 0
    while count < len(chart):
        song_titles_2019.append(chart[count].title)
        count += 1

# %%
for i in range(100):
        song_titles_2019.append(" ")

# %%
# Spotify App Credentials 2015
# CLIENT_ID = "aaf3f0bbaff74d50a1b8a244e4364bdf"
# CLIENT_SECRET = "832f4869770d40ab9d503d1eeaaba8ce"

# credentials = oauth2.SpotifyClientCredentials(
#         client_id=CLIENT_ID,
#         client_secret=CLIENT_SECRET)

# token = credentials.get_access_token()
# spotify = spotipy.Spotify(auth=token)

# %%
len(song_titles_2016)

# %%
song_titles_2016

# %%
df_15_to_19 = pd.DataFrame({"2015": song_titles_2015,"2016": song_titles_2016,"2017": song_titles_2017,"2018": song_titles_2018,"2019": song_titles_2019})
df_15_to_19.head()

# %%
df_15_to_19.to_csv("Resources/2015to2019.csv")

# %%
ids_2015 = []
for track in output_2015:
     # remove tracks that doesn't have corresponding id on Spotify
    if len(track['tracks']['items']) >= 1: 
        ids_2015.append(track['tracks']['items'][0]['id'])

# %%
len(ids_2015)

# %%
i = 0
features_2015 = []
while i < len(ids_2015):
    if i+100 < len(ids_2015):
        features_2015.append(spotify.audio_features(ids_2015[i:i+100]))
    else:
        features_2015.append(spotify.audio_features(ids_2015[i:]))
#     print(i)
    i += 100

# %%
features_2015_cleaned = []

for feature in features_2015:
#    print(len(feature))
     for lst in feature:
         if lst != None:
             features_2015_cleaned.append(lst)

# %%
df_2015 = pd.DataFrame(features_2015_cleaned)

# %%
len(df_2015)

# %%
df_2015.to_csv("Resources/2015data_final.csv")

# %%
df_2015_cleaned = df_2015.drop_duplicates(subset="id", keep='first', inplace=False)

# %% [markdown]
# ## Filter songs (2015-2019) and get Spotify Features

# %%
import pandas as pd

# %%
charts_df = pd.read_csv("Resources/2015to2019_charts.csv")

# %%
charts_df.tail()
# Out:
#       Unnamed: 0                             2015               2016  \
# 1195        1195                    Temporary Fix         Greenlight
# 1196        1196  I Know What You Did Last Summer  A Guy With A Girl
# 1197        1197                            Trust            Wishing
# 1198        1198                         My House         Call On Me
# 1199        1199                     Never Enough         Goosebumps
#
#                  2017                 2018 2019
# 1195         The Plan          Millionaire
# 1196       Pick It Up           Ocean Eyes
# 1197          Go Flex          Close To Me
# 1198  Too Much To Ask        Girl Like You
# 1199      Patek Water  Burn The House Down

# %%
selected_songs_df = pd.read_excel("Resources/2015to2019_song_list_cleanup.xlsx")

# %%
selected_songs_df.tail(10)
# Out:
#           Artist  Year                      Title_Original  \
# 515  Nicki Minaj  2018                             Chun-Li
# 516  Nicki Minaj  2018                                 LLC
# 517  Nicki Minaj  2018                           Good Form
# 518  Nicki Minaj  2018                            Nip Tuck
# 519  Nicki Minaj  2018              2 Lit 2 Late Interlude
# 520  Nicki Minaj  2018                   Come See About Me
# 521  Nicki Minaj  2018              Sir (featuring Future)
# 522  Nicki Minaj  2018                               Miami
# 523  Nicki Minaj  2018  Coco Chanel (featuring Foxy Brown)
# 524  Nicki Minaj  2018                Inspirations (Outro)
#
#               Title_Cleaned
# 515                 Chun-Li
# 516                     LLC
# 517               Good Form
# 518                Nip Tuck
# 519  2 Lit 2 Late Interlude
# 520       Come See About Me
# 521                     Sir
# 522                   Miami
# 523             Coco Chanel
# ...

# %%
selected_songs_df = selected_songs_df.sort_values(by=['Year'], ascending = True)

# %%
selected_songs_df = selected_songs_df[["Artist", "Year","Title_Cleaned"]]

# %%
selected_songs_df.head()
# Out:
#            Artist  Year Title_Cleaned
# 181  Selena Gomez  2015  Good for You
# 185  Selena Gomez  2015     Body Heat
# 186  Selena Gomez  2015          Rise
# 377  Shawn Mendes  2015       Strings
# 378  Shawn Mendes  2015    Aftertaste

# %%
songs_2015 = selected_songs_df.loc[selected_songs_df['Year'] == 2015,["Title_Cleaned"]]

# %%
songs_2015
# Out:
#                    Title_Cleaned
# 181                 Good for You
# 185                    Body Heat
# 186                         Rise
# 377                      Strings
# 378                   Aftertaste
# 379                          Air
# 380                        Crazy
# 184                    Survivors
# 381            A Little Too Much
# 316                        Ghost
# 315                    Young God
# 314                      Control
# 374                  Kid In Love
# 312                  Coming Down
# 311                       Colors
# 382        This Is What It Takes
# 183              Me & the Rhythm
# 182                   Camouflage
# 454                    Shameless
# 460                        Angel
# 373               Never Be Alone
# 372                     Stitches
# 371            Life of the Party
# 459                     Prisoner
# 458                   Dark Times
# 457                   As You Are
# 456                 In the Night
# ...

# %%
songs_2015 = songs_2015["Title_Cleaned"].tolist()
songs_2015
# Out:
# ['Good for You',
#  'Body Heat',
#  'Rise',
#  'Strings',
#  'Aftertaste',
#  'Air',
#  'Crazy',
#  'Survivors',
#  'A Little Too Much',
#  'Ghost',
#  'Young God',
#  'Control',
#  'Kid In Love',
#  'Coming Down',
#  'Colors',
#  'This Is What It Takes',
#  'Me & the Rhythm',
#  'Camouflage',
#  'Shameless',
#  'Angel',
#  'Never Be Alone',
#  'Stitches',
#  'Life of the Party',
#  'Prisoner',
#  'Dark Times',
#  'As You Are',
#  'In the Night',
#  'Something Big',
#  'Earned It',
#  'Revival',
#  'Kill Em with Kindness',
#  'Hands to Myself',
#  'Same Old Love',
#  'Sober',
#  'Roman Holiday',
#  'Drive',
#  'Haunting',
#  'Hold Me Down',
#  'I Know What You Did Last Summer',
#  'New Americana',
#  'Gold',
#  'Smoke and Mirrors',
#  "I'm So Sorry",
#  'I Bet My Life',
#  'Imagination',
#  'Polaroid',
#  'It Comes Back to You',
#  'Dream',
#  'Trouble',
#  'Summer',
#  'Hopeless Opus',
#  'The Fall',
#  'Friction',
#  'The Weight',
#  'Shots',
#  'Lost',
#  'Castle',
# ...

# %%
songs_2016 = selected_songs_df.loc[selected_songs_df['Year'] == 2016,["Title_Cleaned"]]
songs_2016 = songs_2016["Title_Cleaned"].tolist()
songs_2016
# Out:
# ["Sinner's Prayer",
#  'Come to Mama',
#  'Perfect Illusion',
#  "Dancin' in Circles",
#  'John Wayne',
#  'Joanne',
#  'A-Yo',
#  'Bad Reputation',
#  'Understand',
#  'Million Reasons',
#  'Views',
#  9,
#  'Too Good to Say Goodbye',
#  'Finesse',
#  'Calling All My Lovelies',
#  'Straight Up & Down',
#  'Versace on the Floor',
#  "That's What I Like",
#  'Perm',
#  'Chunky',
#  '24K Magic',
#  'Hey Girl',
#  'Hotline Bling',
#  'Fire & Desire',
#  'Summers Over Interlude',
#  'Too Good',
#  'Pop Style',
#  'Childs Play',
#  'Grammys',
#  'One Dance',
#  'Controlla',
#  'Still Here',
#  'Faithful',
#  'With You',
#  'Redemption',
#  'Weston Road Flows',
#  'Hype',
#  'Feel No Ways',
#  'U with Me?',
#  'Keep the Family Close',
#  'Angel Down',
#  'Diamond Heart',
#  '35 Pa Las 12',
#  'Solitario',
#  'Broken Glass',
#  'Space Between',
#  'Honest',
#  'Close to You',
#  'Higher',
#  'Love on the Brain',
#  'Ginza',
#  'Never Ending',
#  'Yeah, I Said It',
#  'Needed Me',
#  'Woo',
# ...

# %%
songs_2017 = selected_songs_df.loc[selected_songs_df['Year'] == 2017,["Title_Cleaned"]]
songs_2017 = songs_2017["Title_Cleaned"].tolist()
songs_2017
# Out:
# ['Him',
#  "Don't Say",
#  'Something Just Like This',
#  'My Type',
#  "It Won't Kill Ya",
#  'Paris',
#  'Honest',
#  'Wake Up Alone',
#  'Young',
#  'Last Day Alive',
#  'Pray',
#  'Palace',
#  'No Peace',
#  'Say It First',
#  'One Last Song',
#  'Midnight Train',
#  'Baby, You Make Me Crazy',
#  'Burning',
#  'Too Good at Goodbyes',
#  'Party Favor',
#  'Shot Down',
#  '100 Letters',
#  'The Prologue',
#  'Dancing in the Dark',
#  'Start Over',
#  'Thunder',
#  'Mouth of the River',
#  'Yesterday',
#  "I'll Make It Up to You",
#  'Rise Up',
#  'Walking the Wire',
#  'Believer',
#  'Whatever It Takes',
#  "I Don't Know Why",
#  'American Teen',
#  'Young Dumb & Broke',
#  'Location',
#  'Another Sad Love Song',
#  'Saved',
#  'Coaster',
#  '8teen',
#  "Let's Go",
#  'Now or Never',
#  'Bloodstream',
#  'Sorry',
#  'Hopeless',
#  'Cold Blooded',
#  'Winter',
#  'Therapy',
#  'Keep Me',
#  'Angels',
#  'Break Up Every Night',
#  'Hopeless',
#  'Good Mourning',
# ...

# %%
songs_2018 = selected_songs_df.loc[selected_songs_df['Year'] == 2018,["Title_Cleaned"]]
songs_2018 = songs_2018["Title_Cleaned"].tolist()
songs_2018
# Out:
# ["When You're Ready",
#  'Perfectly Wrong',
#  'Mutual',
#  'Youth',
#  'Queen',
#  'Because I Had You',
#  'West Coast',
#  'Somewhere Over the Rainbow',
#  'Before I Cry',
#  'Too Far Gone',
#  'Twelve Notes',
#  "I'll Never Love Again",
#  "I'll Never Love Again",
#  'Ganja Burn',
#  'Majesty',
#  'Barbie Dreams',
#  'Rich Sex',
#  'Hard White',
#  'Scene 98',
#  'Bed',
#  'Run & Hide',
#  'Chun Swae',
#  'Chun-Li',
#  'LLC',
#  'Good Form',
#  'Nip Tuck',
#  '2 Lit 2 Late Interlude',
#  'Come See About Me',
#  'Sir',
#  'Miami',
#  'Thought I Knew You',
#  'Hair Body Face',
#  'Why',
#  'Why Did You Do That?',
#  'Fabulous French',
#  'La Vie en rose',
#  "I'll Wait for You",
#  "Maybe It's Time",
#  'Parking Lot',
#  'Out of Time',
#  'Alibi',
#  'Trust Me',
#  'Shallow',
#  'First Stop, Arizona',
#  'Music to My Eyes',
#  "Diggin' My Grave",
#  'I Love You',
#  'Always Remember Us This Way',
#  'Unbelievable',
#  'How Do You Hear It?',
#  'Look What I Found',
#  'Memphis',
# ...

# %%
songs_2019 = selected_songs_df.loc[selected_songs_df['Year'] == 2019,["Title_Cleaned"]]
songs_2019 = songs_2019["Title_Cleaned"].tolist()
songs_2019
# Out:
# ['Genius',
#  'Angel in Your Eyes',
#  'Welcome to the Wonderful World Of',
#  'Outta My Head',
#  'Audio',
#  'Hundred',
#  'My Bad',
#  'Better',
#  'Talk',
#  'Right Back',
#  "Don't Pretend",
#  'Thunderclouds',
#  'Paradise',
#  'Mountains',
#  'Alive',
#  'Free Spirit',
#  'Heaven',
#  'Saturday Nights',
#  'Mojaita',
#  'Yo Le Llego',
#  'Cuidao por Ahí',
#  'Qué Pretendes',
#  'La Canción',
#  'No New Friends',
#  'Un Peso',
#  'Self',
#  "Bluffin'",
#  'Thank U, next',
#  'Twenty One',
#  'Genius',
#  "It's Time",
#  'Heaven Can Wait',
#  'Como un Bebé',
#  'Odio',
#  'Feels',
#  'Bad Guy',
#  'Paper Rings',
#  'Cornelia Street',
#  'Death by a Thousand Cuts',
#  'London Boy',
#  "Soon You'll Get Better",
#  'False God',
#  'You Need to Calm Down',
#  'Afterglow',
#  'Me!',
#  "It's Nice to Have a Friend",
#  'Daylight',
#  'Push My Luck',
#  'Takeaway',
#  'Call You Mine',
#  'Do You Mean',
#  'Kills You Slowly',
#  'Who Do You Love',
#  'Peace of Mind',
#  'Heaven',
# ...

# %%
charts_2015 = charts_df["2015"].tolist()

# %%
len(charts_2015)
# Out:
# 1200

# %%
charts_2016 = charts_df["2016"].tolist()
len(charts_2016)
# Out:
# 1200

# %%
charts_2017 = charts_df["2017"].tolist()
charts_2018 = charts_df["2018"].tolist()
charts_2019 = charts_df["2019"].tolist()

# %%
charts_2019[-1]
# Out:
# ' '

# %%
charts_2019_cleaned = [item for item in charts_2019 if item != " "]

# charts_2019_cleaned = []

# for item in charts_2019:
#     if item != " ":
#         charts_2019_cleaned.append(item)

# %%
charts_2019_cleaned
# Out:
# ['Thank U, Next',
#  'Without Me',
#  'All I Want For Christmas Is You',
#  'Sicko Mode',
#  'Sunflower (Spider-Man: Into The Spider-Verse)',
#  'High Hopes',
#  'Happier',
#  'Jingle Bell Rock',
#  "Rockin' Around The Christmas Tree",
#  'A Holly Jolly Christmas',
#  'The Christmas Song (Merry Christmas To You)',
#  'Drip Too Hard',
#  "It's The Most Wonderful Time Of The Year",
#  'Girls Like You',
#  'ZEZE',
#  'Rudolph The Red-Nosed Reindeer',
#  'Mo Bamba',
#  'Wake Up In The Sky',
#  'Money',
#  'Let It Snow, Let It Snow, Let It Snow',
#  'Eastside',
#  'Breathin',
#  'Better Now',
#  'Youngblood',
#  'Last Christmas',
#  'Sleigh Ride',
#  'Lucid Dreams',
#  'Here Comes Santa Claus (Right Down Santa Claus Lane)',
#  'Feliz Navidad',
#  'Taki Taki',
#  'MIA',
#  "(There's No Place Like) Home For The Holidays",
#  'Leave Me Alone',
#  'White Christmas',
#  "It's Beginning To Look A Lot Like Christmas",
#  'Going Bad',
#  'A Lot',
#  'Trip',
#  'I Like It',
#  'Blue Christmas',
# ...

# %%
len(charts_2019)
# Out:
# 1200

# %%
len(charts_2019_cleaned)
# Out:
# 1100

# %%
charts_2019_songs_df = pd.DataFrame({"song_titles": charts_2019_cleaned})
charts_2019_songs_df
# Out:
#                                             song_titles
# 0                                         Thank U, Next
# 1                                            Without Me
# 2                       All I Want For Christmas Is You
# 3                                            Sicko Mode
# 4         Sunflower (Spider-Man: Into The Spider-Verse)
# 5                                            High Hopes
# 6                                               Happier
# 7                                      Jingle Bell Rock
# 8                     Rockin' Around The Christmas Tree
# 9                               A Holly Jolly Christmas
# 10          The Christmas Song (Merry Christmas To You)
# 11                                        Drip Too Hard
# 12             It's The Most Wonderful Time Of The Year
# 13                                       Girls Like You
# 14                                                 ZEZE
# 15                       Rudolph The Red-Nosed Reindeer
# ...

# %%
charts_2019_songs_df.to_csv("Resources/2019popular_songtitles.csv")

# %%
charts_2015to2019 = charts_2015 + charts_2016 + charts_2017 + charts_2018 + charts_2019_cleaned
len(charts_2015to2019)
# Out:
# 5900

# %%
songs_2015to2019 = songs_2015 + songs_2016 + songs_2017 + songs_2018 + songs_2019
len(songs_2015to2019)
# Out:
# 525

# %%
unpopular_songs = [item for item in songs_2015to2019 if item not in charts_2015to2019]

# %%
unpopular_songs
# Out:
# ['Good for You',
#  'Body Heat',
#  'Strings',
#  'Aftertaste',
#  'Air',
#  'Crazy',
#  'Survivors',
#  'A Little Too Much',
#  'Young God',
#  'Control',
#  'Kid In Love',
#  'Coming Down',
#  'Colors',
#  'This Is What It Takes',
#  'Me & the Rhythm',
#  'Camouflage',
#  'Angel',
#  'Never Be Alone',
#  'Life of the Party',
#  'As You Are',
#  'In the Night',
#  'Something Big',
#  'Earned It',
#  'Revival',
#  'Kill Em with Kindness',
#  'Hands to Myself',
#  'Roman Holiday',
#  'Drive',
#  'Haunting',
#  'Hold Me Down',
#  'Smoke and Mirrors',
#  "I'm So Sorry",
#  'Imagination',
#  'Polaroid',
#  'It Comes Back to You',
#  'Dream',
#  'Summer',
#  'Hopeless Opus',
#  'The Fall',
#  'Friction',
#  'The Weight',
#  'Lost',
#  'Castle',
#  "Don't Want Your Love",
#  'Losers',
#  "I Don't Even Know Your Name",
#  'Handwritten Demos',
#  'Running Low',
#  'Act Like You Love Me',
#  'Bring It Back',
#  "Sinner's Prayer",
#  'Come to Mama',
#  "Dancin' in Circles",
#  'John Wayne',
# ...

# %%
len(unpopular_songs)
# Out:
# 383

# %%
unpopular_songs_df = pd.DataFrame({"song_titles": unpopular_songs})
unpopular_songs_df
# Out:
#                                 song_titles
# 0                              Good for You
# 1                                 Body Heat
# 2                                   Strings
# 3                                Aftertaste
# 4                                       Air
# 5                                     Crazy
# 6                                 Survivors
# 7                         A Little Too Much
# 8                                 Young God
# 9                                   Control
# 10                              Kid In Love
# 11                              Coming Down
# 12                                   Colors
# 13                    This Is What It Takes
# 14                          Me & the Rhythm
# 15                               Camouflage
# 16                                    Angel
# 17                           Never Be Alone
# 18                        Life of the Party
# 19                               As You Are
# ...

# %%
unpopular_songs_df.to_csv("Resources/unpopular_songtitles.csv")

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2

# %%
market = [ "AD", "AR", "AT", "AU", "BE", "BG", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", 
      "CZ", "DE", "DK", "DO", "EC", "EE", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", 
      "ID", "IE", "IS", "IT", "JP", "LI", "LT", "LU", "LV", "MC", "MT", "MX", "MY", "NI", "NL", 
      "NO", "NZ", "PA", "PE", "PH", "PL", "PT", "PY", "SE", "SG", "SK", "SV", "TH", "TR", "TW", 
      "US", "UY", "VN" ]

# %%
# Spotify App Credentials Unpopular
CLIENT_ID = "b57f6140a6334fe0b9a992c56dc8991c"
CLIENT_SECRET = "eed42920b4e841059986b7676762933b"

credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)

# %%
output_unpopular = []
for title in unpopular_songs:
  output_unpopular.append(spotify.search(title, type="track", market=market, limit=1))

# %%
ids_unpopular = []
for track in output_unpopular:
    # remove tracks that doesn't have corresponding id on Spotify
    if len(track['tracks']['items']) >= 1: 
        ids_unpopular.append(track['tracks']['items'][0]['id'])

# %%
len(ids_unpopular)
# Out:
# 381

# %%
i = 0
features_unpopular = []
while i < len(ids_unpopular):
    if i+100 < len(ids_unpopular):
        features_unpopular.append(spotify.audio_features(ids_unpopular[i:i+100]))
    else:
        features_unpopular.append(spotify.audio_features(ids_unpopular[i:]))
#     print(i)
    i += 100

# %%
features_unpopular_cleaned = []

for feature in features_unpopular:
#    print(len(feature))
     for lst in feature:
         if lst != None:
             features_unpopular_cleaned.append(lst)

# %%
len(features_unpopular_cleaned)
# Out:
# 381

# %%
df_unpopular = pd.DataFrame(features_unpopular_cleaned)

# %%
df_unpopular.head()
# Out:
#    acousticness                                       analysis_url  \
# 0      0.170000  https://api.spotify.com/v1/audio-analysis/5hTp...
# 1      0.189000  https://api.spotify.com/v1/audio-analysis/75rn...
# 2      0.129000  https://api.spotify.com/v1/audio-analysis/3gzv...
# 3      0.000323  https://api.spotify.com/v1/audio-analysis/3ilt...
# 4      0.551000  https://api.spotify.com/v1/audio-analysis/18AX...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.941       209640   0.335  5hTpBe8h35rJ67eAWHQsJx
# 1         0.740       207733   0.974  75rnLkvIeq8RZ8xjcFIvSG
# 2         0.795       194000   0.557  3gzvOfEsblYOVK3xDXodCP
# 3         0.637       169573   0.509  3ilt7lMNflb49pEDpcZPAa
# 4         0.446       336453   0.239  18AXbzPzBS8Y3AkgSxzJPb
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    5    0.2620   -10.179     0       0.5050  120.041
# ...

# %%
df_unpopular.to_csv("Resources/unpopulardata.csv")
